# %%
from light_curve_util import kepler_io
import matplotlib.pyplot as plt
import numpy as np
import os
import matplotlib
# %matplotlib inline
font = {        'size'   : 20}
matplotlib.rc('font', **font)

# %%
KEPLER_DATA_DIR = "/home/idies/workspace/Storage/tdo/planets_ml/data"
KEPLER_ID = 11442793  # Kepler-90.

# %%
# Read the light curve.
file_names = kepler_io.kepler_filenames(KEPLER_DATA_DIR, KEPLER_ID)
print(file_names)
assert file_names, "Failed to find .fits files in {}".format(KEPLER_DATA_DIR)
all_time, all_flux = kepler_io.read_kepler_light_curve(file_names)
print("Read light curve with {} segments".format(len(all_time)))
# Out:
# ['/home/idies/workspace/Storage/tdo/planets_ml/data/0114/011442793/kplr011442793-2009166043257_llc.fits', '/home/idies/workspace/Storage/tdo/planets_ml/data/0114/011442793/kplr011442793-2009259160929_llc.fits', '/home/idies/workspace/Storage/tdo/planets_ml/data/0114/011442793/kplr011442793-2009350155506_llc.fits', '/home/idies/workspace/Storage/tdo/planets_ml/data/0114/011442793/kplr011442793-2010009091648_llc.fits', '/home/idies/workspace/Storage/tdo/planets_ml/data/0114/011442793/kplr011442793-2010174085026_llc.fits', '/home/idies/workspace/Storage/tdo/planets_ml/data/0114/011442793/kplr011442793-2010265121752_llc.fits', '/home/idies/workspace/Storage/tdo/planets_ml/data/0114/011442793/kplr011442793-2010355172524_llc.fits', '/home/idies/workspace/Storage/tdo/planets_ml/data/0114/011442793/kplr011442793-2011177032512_llc.fits', '/home/idies/workspace/Storage/tdo/planets_ml/data/0114/011442793/kplr011442793-2011271113734_llc.fits', '/home/idies/workspace/Storage/tdo/planets_ml/data/0114/011442793/kplr011442793-2012004120508_llc.fits', '/home/idies/workspace/Storage/tdo/planets_ml/data/0114/011442793/kplr011442793-2012179063303_llc.fits', '/home/idies/workspace/Storage/tdo/planets_ml/data/0114/011442793/kplr011442793-2012277125453_llc.fits', '/home/idies/workspace/Storage/tdo/planets_ml/data/0114/011442793/kplr011442793-2013011073258_llc.fits', '/home/idies/workspace/Storage/tdo/planets_ml/data/0114/011442793/kplr011442793-2013131215648_llc.fits']
# Read light curve with 14 segments

# %%
# Plot the fourth segment.
plt.plot(all_time[3], all_flux[3], ".")

# %%
# Plot all light curve segments. We first divide by the median flux in each
# segment, because the segments are on different scales.
for f in all_flux:
  f /= np.median(f)
plt.figure(figsize=(12,6))
plt.plot(np.concatenate(all_time), np.concatenate(all_flux), ".")
